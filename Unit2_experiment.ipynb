# %%
! pip install -Uqq transformers datasets huggingsound

# %%
from transformers import pipeline
from IPython.display import Audio as ipd
from datasets import load_dataset, Audio

from huggingsound import SpeechRecognitionModel

# %%
minds = load_dataset("PolyAI/minds14", name="en-AU", split="train")

asr = pipeline("automatic-speech-recognition")
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# No model was supplied, defaulted to facebook/wav2vec2-base-960h and revision 55bb623 (https://huggingface.co/facebook/wav2vec2-base-960h).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Dataset minds14 downloaded and prepared to /root/.cache/huggingface/datasets/PolyAI___minds14/en-AU/1.0.0/65c7e0f3be79e18a6ffaf879a083daf706312d421ac90d25718459cbf3c42696. Subsequent calls will reuse this data.
# ...
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...

# %%
example = minds[0]
example
# Out:
# {'path': '/root/.cache/huggingface/datasets/downloads/extracted/a19fbc5032eacf25eab0097832db7b7f022b42104fbad6bd5765527704a428b9/en-AU~PAY_BILL/response_4.wav',
#  'audio': {'path': '/root/.cache/huggingface/datasets/downloads/extracted/a19fbc5032eacf25eab0097832db7b7f022b42104fbad6bd5765527704a428b9/en-AU~PAY_BILL/response_4.wav',
#   'array': array([ 0.        ,  0.00024414, -0.00024414, ..., -0.00024414,
#           0.00024414,  0.0012207 ]),
#   'sampling_rate': 8000},
#  'transcription': 'I would like to pay my electricity bill using my card can you please assist',
#  'english_transcription': 'I would like to pay my electricity bill using my card can you please assist',
#  'intent_class': 13,
#  'lang_id': 2}

# %%
ipd(example["path"])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
asr(example["audio"]["array"])
# Out:
# {'text': "AT'LL ROUT THE PONOTTE FLFLOOR ALL THE MATTER THE LITTLE"}

# %%
# asr_download = pipeline("automatic-speech-recognition", model="jonatasgrosman/wav2vec2-large-xlsr-53-english")
# Out:
# ...
# Could not load the `decoder` for jonatasgrosman/wav2vec2-large-xlsr-53-english. Defaulting to raw CTC. Error: No module named 'kenlm'
# Try to install `kenlm`: `pip install kenlm
# Try to install `pyctcdecode`: `pip install pyctcdecode

# %%
# asr_download(example["audio"]["array"])
# Out:
# {'text': 'i will wrap the plmout of twafotor olven my tog sone trolve of fof'}

# %%
model = SpeechRecognitionModel("jonatasgrosman/wav2vec2-large-xlsr-53-english")
# Out:
# INFO:huggingsound.speech_recognition.model:Loading model...

# %%
audio_paths = [example["path"]]

transcriptions = model.transcribe(audio_paths)

print(transcriptions)
# Out:
# 100%|██████████| 1/1 [00:08<00:00,  8.15s/it]
# ...
